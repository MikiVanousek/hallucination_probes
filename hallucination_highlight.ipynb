# %%
from IPython.display import HTML, display

text = "This is <span style='background-color: #ffcccc;'>hallucinated</span> and this is <span style='background-color: #ccffcc;'>correct</span>."
display(HTML(text))
# Out:
# This is <span style='background-color: #ffcccc;'>hallucinated</span> and this is <span style='background-color: #ccffcc;'>correct</span>.
